# %%
import numpy as np
import seaborn as sns

import pandas as pd
import math
import matplotlib.pyplot as plt
import cv2
from sklearn.model_selection import train_test_split, StratifiedKFold
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, Convolution2D, Conv2D, MaxPooling2D, Lambda, GlobalMaxPooling2D, GlobalAveragePooling2D, BatchNormalization, Activation, AveragePooling2D, Concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
X_test = pd.read_csv("/home/ali/Desktop/MAP569_Project/AMF_test_X_uDs0jHH.csv")
X_train = pd.read_csv("/home/ali/Desktop/MAP569_Project/AMF_train_X_XCZw8r3.csv")
Y_train = pd.read_csv("/home/ali/Desktop/MAP569_Project/AMF_train_Y_omYQJZL.csv")

# %%
X_train.isna().any()
# Out:
# Index                         False
# Share                         False
# Day                           False
# Trader                        False
# OTR                            True
# OCR                           False
# OMR                            True
# min_time_two_events           False
# mean_time_two_events          False
# 10_p_time_two_events          False
# med_time_two_events           False
# 25_p_time_two_events          False
# 75_p_time_two_events          False
# 90_p_time_two_events          False
# max_time_two_events           False
# min_lifetime_cancel           False
# mean_lifetime_cancel          False
# 10_p_lifetime_cancel          False
# med_lifetime_cancel           False
# 25_p_lifetime_cancel          False
# 75_p_lifetime_cancel          False
# 90_p_lifetime_cancel          False
# max_lifetime_cancel           False
# NbTradeVenueMic               False
# MaxNbTradesBySecond           False
# MeanNbTradesBySecond          False
# ...

# %%
# Replacement by median the nan values
X_train['OTR'].fillna(1.0,inplace=True)
X_train['OMR'].fillna(1.0,inplace=True)

X_train['min_dt_TV1'].fillna(0.000091,inplace=True)
X_train['mean_dt_TV1'].fillna(183.022816,inplace=True)
X_train['med_dt_TV1'].fillna(36.457000,inplace=True)
X_train['min_dt_TV1_TV2'].fillna(0.000232,inplace=True)
X_train['mean_dt_TV1_TV2'].fillna(110.427370,inplace=True)
X_train['med_dt_TV1_TV2'].fillna(22.413161,inplace=True)
X_train['min_dt_TV1_TV3'].fillna(0.000260,inplace=True)
X_train['mean_dt_TV1_TV3'].fillna(111.633327,inplace=True)
X_train['med_dt_TV1_TV3'].fillna(23.665962,inplace=True)
X_train['min_dt_TV1_TV4'].fillna(0.000270,inplace=True)
X_train['mean_dt_TV1_TV4'].fillna(113.158721,inplace=True)
X_train['med_dt_TV1_TV4'].fillna(23.435835,inplace=True)

# %%
X_train.describe()
# Out:
#                Index            OTR            OCR            OMR  \
# count  105782.000000  105782.000000  105782.000000  105782.000000
# mean    52891.500000       2.469924      17.458787      90.892426
# std     30536.777425       1.232401      71.843225     693.694178
# min         1.000000       0.693147       2.000000       1.000000
# 25%     26446.250000       1.527608       2.753802       1.000000
# 50%     52891.500000       2.097141       4.789474       1.589310
# 75%     79336.750000       3.141593      16.366667      18.333333
# max    105782.000000       9.773493   14409.000000  127861.000000
#
#        min_time_two_events  mean_time_two_events  10_p_time_two_events  \
# count        105782.000000         105782.000000         105782.000000
# mean             87.472164           2772.513578            103.310102
# std            1549.972501           4985.149536           1617.051421
# min               0.000000              0.000065              0.000000
# ...

# %%
clas = []
for i in range(105782):
    for j in range(86):
        if X_train['Trader'][i] == Y_train['Trader'][j]:
            clas.append(Y_train['type'][j])
            break

# %%
y = pd.get_dummies(clas)

# %%
corr = data.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.diverging_palette(300, 20, as_cmap=True)


sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=False, linewidths=0.1, cbar_kws={"shrink": .1}, ax = ax)
# Out:
# <AxesSubplot:>

# %%
data = X_train.copy()
data['type'] = clas
hft = pd.get_dummies(data.type, prefix='type')['type_HFT']
mix = pd.get_dummies(data.type, prefix='type')['type_MIX']
non = pd.get_dummies(data.type, prefix='type')['type_NON HFT']

# %%
data['type_HFT'] = hft
data['type_MIX'] = mix 
data['type_NON HFT'] = non

# %%
X_train['OTR'] = np.log( X_train['OTR'] + 1 )

# %%
fig, axs = plt.subplots(6,6,figsize=(30, 30) )
axs[0,0].hist(X_train['OTR'])
axs[0,0].set_title('OTR')
axs[1,0].hist(X_train['OCR'])
axs[1,0].set_title('OCR')                           
axs[2,0].hist(X_train['OMR'])
axs[2,0].set_title('OMR')                            
axs[3,0].hist(X_train['min_time_two_events'])
axs[3,0].set_title('min_time_two_events')           
axs[4,0].hist(X_train['mean_time_two_events'])
axs[4,0].set_title('mean_time_two_events')          
axs[5,0].hist(X_train['10_p_time_two_events'])
axs[5,0].set_title('10_p_time_two_events')          
axs[0,1].hist(X_train['med_time_two_events'])
axs[0,1].set_title('med_time_two_events')           
axs[1,1].hist(X_train['25_p_time_two_events'])
axs[1,1].set_title('25_p_time_two_events')          
axs[2,1].hist(X_train['75_p_time_two_events'])
axs[2,1].set_title('75_p_time_two_events')          
axs[3,1].hist(X_train['90_p_time_two_events'])
axs[3,1].set_title('90_p_time_two_events')          
axs[4,1].hist(X_train['max_time_two_events'])
axs[4,1].set_title('max_time_two_events')           
axs[5,1].hist(X_train['min_lifetime_cancel'])
axs[5,1].set_title('min_lifetime_cancel')           
axs[0,2].hist(X_train['mean_lifetime_cancel'])
axs[0,2].set_title('mean_lifetime_cancel')          
axs[1,2].hist(X_train['10_p_lifetime_cancel'])
axs[1,2].set_title('10_p_lifetime_cancel')          
axs[2,2].hist(X_train['med_lifetime_cancel'])
axs[2,2].set_title('med_lifetime_cancel')           
axs[3,2].hist(X_train['25_p_lifetime_cancel'])
axs[3,2].set_title('25_p_lifetime_cancel')          
axs[4,2].hist(X_train['75_p_lifetime_cancel'])
axs[4,2].set_title('75_p_lifetime_cancel')          
axs[5,2].hist(X_train['90_p_lifetime_cancel'])
axs[5,2].set_title('90_p_lifetime_cancel')          
axs[0,3].hist(X_train['max_lifetime_cancel'])
axs[0,3].set_title('max_lifetime_cancel')           
axs[1,3].hist(X_train['NbTradeVenueMic'])
axs[1,3].set_title('NbTradeVenueMic')               
axs[2,3].hist(X_train['MaxNbTradesBySecond'])
axs[2,3].set_title('MaxNbTradesBySecond')           
axs[3,3].hist(X_train['MeanNbTradesBySecond'])
axs[3,3].set_title('MeanNbTradesBySecond')          
axs[4,3].hist(X_train['min_dt_TV1'])
axs[4,3].set_title('min_dt_TV1')                    
axs[5,3].hist(X_train['mean_dt_TV1'])
axs[5,3].set_title('mean_dt_TV1')                   
axs[0,4].hist(X_train['med_dt_TV1'])
axs[0,4].set_title('med_dt_TV1')                    
axs[1,4].hist(X_train['min_dt_TV1_TV2'])
axs[1,4].set_title('min_dt_TV1_TV2')                
axs[2,4].hist(X_train['mean_dt_TV1_TV2'])
axs[2,4].set_title('mean_dt_TV1_TV2')               
axs[3,4].hist(X_train['med_dt_TV1_TV2'])
axs[3,4].set_title('med_dt_TV1_TV2')                
axs[4,4].hist(X_train['min_dt_TV1_TV3'])
axs[4,4].set_title('min_dt_TV1_TV3')                
axs[5,4].hist(X_train['mean_dt_TV1_TV3'])
axs[5,4].set_title('mean_dt_TV1_TV3')               
axs[0,5].hist(X_train['med_dt_TV1_TV3'])
axs[0,5].set_title('med_dt_TV1_TV3')                
axs[1,5].hist(X_train['min_dt_TV1_TV4'])
axs[1,5].set_title('min_dt_TV1_TV4')                
axs[2,5].hist(X_train['mean_dt_TV1_TV4'])
axs[2,5].set_title('mean_dt_TV1_TV4')               
axs[3,5].hist(X_train['med_dt_TV1_TV4'])
axs[3,5].set_title('med_dt_TV1_TV4')                
axs[4,5].hist(X_train['NbSecondWithAtLeatOneTrade'])
axs[4,5].set_title('NbSecondWithAtLeatOneTrade')
# Out:
# Text(0.5, 1.0, 'NbSecondWithAtLeatOneTrade')

# %%
# Training
# Random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

nRows = X_train.shape[0]
nCols = X_train.shape[1]
# print(X_train.shape)
# print(Y_train.shape)
# print(y.shape)


X_train, y = make_classification(n_samples=nRows, n_features=nCols,
                            n_informative=2, n_redundant=0,
                            random_state=0, shuffle=True)
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X_train, y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=2, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
print("Train accuracy", clf.score(X_train, y))
# Out:
# Train accuracy 0.9084910476262502

# %%
y_test = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-e321c11d0259> in <module>
# ----> 1 y_test = clf.predict(X_test)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     610             The predicted classes.
#     611         """
# --> 612         proba = self.predict_proba(X)
#     613
#     614         if self.n_outputs_ == 1:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     654         check_is_fitted(self)
#     655         # Check data
# --> 656         X = self._validate_X_predict(X)
#     657
#     658         # Assign chunk of trees to jobs
#
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     410         check_is_fitted(self)
#     411
# ...
